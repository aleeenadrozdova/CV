# %%
import numpy as np
import sympy
from sympy import S, Symbol, symbols, solve, solveset, plot, plot_parametric, And, plot_implicit
from sympy import sin as Sin
from sympy import cos as Cos
from sympy import exp as Exp
from sympy import log as Log
from sympy import pi as Pi
from sympy.plotting import plot3d
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Занятие 14
# ## Математический анализ
# ## Функции нескольких переменных.
# ### Задание 1
# Изобразить на рисунках область определения функций
#
# 1) $z=\ln(x^2+y)$
#
# 2) $z=\sqrt{\sin(x^2+y^2)}$
#
# 3) $z=\sqrt{x^2-4}+\sqrt{9-y^2}$

# %%
x, y = symbols('x y', real=True)
domainz = (x**2 + y > 0)
plot_implicit(domainz)

# %%
x, y = symbols('x y', real=True)
domainz = (Sin(x**2 + y**2) >= 0)
plot_implicit(domainz)

# %%
x, y = symbols('x y', real=True)
domainz = ((x**2 - 4 >= 0) & (9 - y**2 >= 0))
plot_implicit(domainz)

# %% [markdown]
# ### Задача 2.
# Построить на отдельных графиках линии уровня функций $z=\ln(x^2+y)$ и $z=x^2-y^2$.

# %%
C = symbols('C', real=True)
def contourline(f, x, y, C):
    return sympy.Eq(f(x, y), C)
def f(x, y):
    return Log(x**2 + y)
p = plot(ylabel='y', show=False)
for item in [(-2, 'blue'), (-1, 'green'), (0, 'red'), (1, 'black'), (2, 'pink')]:
    c, col = item
    p.append(plot_implicit(contourline(f, x, y, c), line_color=col, line_width=15, show=False)[0])
p.show()

# %%
C = symbols('C', real=True)
def contourline(f, x, y, C):
    return sympy.Eq(f(x, y), C)
def f(x, y):
    return x**2 - y**2
p = plot(ylabel='y', show=False)
for item in [(-2, 'blue'), (-1, 'green'), (0, 'red'), (1, 'black'), (2, 'pink')]:
    c, col = item
    p.append(plot_implicit(contourline(f, x, y, c), line_color=col, line_width=15, show=False)[0])
p.show()

# %% [markdown]
# ### Задача 3.
# Найти и изобразить поверхности уровня функции $u=(x-1)^2+(y-2)^2+z^2$.

# %%
z, c = symbols('z c')
u = (x - 1)**2 + (y - 2)**2 + z**2
z12 = solve(sympy.Eq(u, c), z)
display(*z12)
plot3d(z12[0].subs(c, 1), z12[1].subs(c, 1))
plot3d(z12[0].subs(c, 5), z12[1].subs(c, 5))
# Out:
# -sqrt(c - x**2 + 2*x - y**2 + 4*y - 5)
# sqrt(c - x**2 + 2*x - y**2 + 4*y - 5)

# %% [markdown]
# ### Задача 4.
# Найти точки разрыва функции $z=\frac1{(x - y^2)^2}$, изобразить их на графике.

# %%
plot_implicit((x - y**2)**2, (x, -0.5, 2), (y, -2, 2))

# %% [markdown]
# ### Задача 5.
# Найти частные производные по каждому аргументу функции $u=(xy)^z$

# %%
u = (x*y)**z
display(*(u.diff(t) for t in (x, y, z)))
# Out:
# z*(x*y)**z/x
# z*(x*y)**z/y
# (x*y)**z*log(x*y)

# %% [markdown]
# ### Задача 6.
# Проверить выполнение теоремы Эйлера для функции $f(x,y)=\frac{x}{x^2+y^2} $.
# ###### Указание.
# Упростить выражение с помощью simplify, прежде чем сравнивать.

# %%
k = symbols('k', real=True)
f = x/(x**2+y**2)
display(sympy.simplify(f.subs({x: k*x, y: k*y})))
print("Функция однородна, измерение равно -1")
display(sympy.simplify(x*f.diff(x) + y*f.diff(y)))
sympy.simplify(x*f.diff(x) + y*f.diff(y)) == -f
# Out:
# x/(k*(x**2 + y**2))
# Функция однородна, измерение равно -1
# -x/(x**2 + y**2)
# True

# %% [markdown]
# ### Задача 7.
# Найти полный дифференциал функции $z=\sin^2x+\cos^2y$

# %%
z = Sin(x)**2 + Cos(y)**2
dx, dy = symbols('dx dy')
dz = z.diff(x)*dx + z.diff(y)*dy
dz
# Out:
# 2*dx*sin(x)*cos(x) - 2*dy*sin(y)*cos(y)

# %% [markdown]
# ### Индивидуальное задание
# Построить линии уровня и найти полный дифференциал функции
# $f(x, y)= \arcsin (6xy)$.

# %%
C = symbols('C', real=True)
def contourline(f, x, y, C):
    return sympy.Eq(f(x, y), C)
def f(x, y):
    return sympy.asin(6*x*y)
p = plot(ylabel='y', show=False)
for item in [(-1, 'blue'), (-0.5, 'green'), (0, 'red'), (0.5, 'black'), (1, 'pink')]:
    c, col = item
    p.append(plot_implicit(contourline(f, x, y, c), (x, -0.5, 0.5), (y, -2, 2), line_color=col, line_width=15, show=False)[0])
p.show()

# %%
z = sympy.asin(6*x*y)
dx, dy = symbols('dx dy')
dz = z.diff(x)*dx + z.diff(y)*dy
dz
# Out:
# 6*dx*y/sqrt(-36*x**2*y**2 + 1) + 6*dy*x/sqrt(-36*x**2*y**2 + 1)
