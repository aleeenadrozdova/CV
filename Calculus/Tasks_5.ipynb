# %% [markdown]
# ## Практическое занятие 5
# ## Математический анализ
# ## Численное решение нелинейных уравнений: nsolve
# https://docs.sympy.org/latest/modules/solvers/solvers.html?highlight=nsolve#sympy.solvers.solvers.nsolve
#
# #### Уравнение в форме $f(x)=0$

# %%
import numpy as np
import sympy
from sympy import nsolve
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Задача 1
# Решить уравнение $𝑥^4−e^x=0$ при $-2 \le x \le 2$, построить график левой части, отметить точки пересечения с осью ОХ.

# %%
def f(x):
    return x**4-np.e**x
x = sympy.Symbol("x")
X = np.linspace(-2, 2, 100)
plt.plot(X, f(X))
ax = plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))
roots = [sympy.nsolve(f(x), x, point) for point in [-1, 1]]
roots
# Out:
# [-8.08901837464658e-7, -2.74841437771327e-7]

# %%
ax = plt.gca() 
for i in range(len(roots)): 
    ax.annotate('A' + str(i + 1),
            xy=(roots[i], 0), xycoords='data',
            xytext=(roots[i]-0.1, 1), textcoords='data')
X = np.linspace(-2, 2, 100)
Y = f(X)
ax = plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))
ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False)
ax.plot(0, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False)
ax.plot(X, Y, color='green', label=r'$f(x) = x^4-e^x$')
ax.legend(loc='upper right')
ax.scatter(roots, [0 for x in range(len(roots))])

# %% [markdown]
# ### Задача 2.
# Решить уравнение $\sin^2(2x)=\ln x$ при $0< x \le 3$. Построить графики левой и правой части, отметить точку пересечения графиков.

# %%
def f(x, lib='sympy'):
    if lib == 'sympy':
        return (sympy.sin(2*x))**2
    if lib == 'numpy':
        return (np.sin(2*x))**2
    return 'error'
def g(x, lib='sympy'):
    if lib == 'sympy':
        return sympy.log(x)
    if lib == 'numpy':
        return np.log(x)
    return 'error'
x = sympy.Symbol("x")
X = np.linspace(0.0001, 3, 100)
plt.plot(X, f(X, 'numpy') - g(X, 'numpy'))
ax = plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))
roots = [sympy.nsolve(sympy.Eq(f(x), g(x)), x, point) for point in [1, 2, 2.5]]
roots
# Out:
# [1.30133323382849, 2.08594344788353, 2.50217038800416]

# %%
y_coords = [f(x) for x in roots]
ax = plt.gca() 
for i in range(len(roots)): 
    ax.annotate('A' + str(i + 1),
            xy=(roots[i], y_coords[i]), xycoords='data',
            xytext=(roots[i]-0.05, y_coords[i]+0.2), textcoords='data')
X = np.linspace(0, 3, 100)
Y_f = f(X, 'numpy')
Y_g = g(X, 'numpy')
ax = plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))
ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False)
ax.plot(0, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False)
ax.plot(X, Y_f, color='green', label=r'$f(x) = \sin^2(2x)$')
ax.plot(X, Y_g, color='skyblue', label=r'$g(x) = \ln x$')
ax.legend(loc='lower right')
ax.scatter(roots, y_coords)
# Out:
# C:\Users\Алёна\AppData\Local\Temp\ipykernel_5876\4102367600.py:11: RuntimeWarning: divide by zero encountered in log
#   return np.log(x)

# %% [markdown]
# ### Задача 3.
# Решить уравнение $\sin^2(2x^2-7x+6)=3/4$ на $[3, 4]$. Построить графики левой и правой части, отметить точки пересечения графиков.

# %%
def f(x, lib='sympy'):
    if lib == 'sympy':
        return (sympy.sin(2*x**2-7*x))**2
    if lib == 'numpy':
        return (np.sin(2*x**2-7*x))**2
    return 'error'
x = sympy.Symbol("x")
X = np.linspace(3, 4, 100)
plt.plot(X, f(X, 'numpy')-0.75)
ax = plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['left'].set_position(('data', 3))
ax.spines['bottom'].set_position(('data', 0))
roots = [sympy.nsolve(f(x, 'sympy')-0.75, x, point) for point in [3, 3.2, 3.65, 3.7]]
roots
# Out:
# [3.16961348570778, 3.34339299119888, 3.64369975856742, 3.77723889840260]

# %%
y_coords = [f(x) for x in roots]
ax = plt.gca() 
for i in range(len(roots)): 
    ax.annotate('A' + str(i + 1),
            xy=(roots[i], y_coords[i]), xycoords='data',
            xytext=(roots[i]-0.01, y_coords[i]+0.1), textcoords='data')
X = np.linspace(3, 4, 100)
Y_f = f(X, 'numpy')
Y_g = [0.75 for x in range(len(X))]
ax = plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['left'].set_position(('data', 3))
ax.spines['bottom'].set_position(('data', 0))
ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False)
ax.plot(3, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False)
ax.plot(X, Y_f, color='green', label=r'$f(x) = \sin^2(2x^2-7x+6)$')
ax.plot(X, Y_g, color='skyblue', label=r'$g(x) = \frac{3}{4}$')
ax.legend(loc='lower right')
ax.scatter(roots, y_coords)

# %% [markdown]
# ### Задача 4.
# Решить уравнение ${\rm tg}^4(2x^2+1)-10=0$ на интервале $[0, 0.2]$ методом дихотомии. График строить не нужно.

# %%
def f(x):
    return (sympy.tan(2*x**2 + 1))**4 - 10
root = sympy.nsolve(f(x), x, [0, 0.2], solver='bisect', verify=False, prec=10)
print(root)
print(f(root)) #практически ноль
# Out:
# 0.1710663775
# -4.656612873e-10

# %% [markdown]
# ### Задача 5.
# Решить систему уравнений
# $$
# \left\{\begin{matrix}
# (x - 1)^2 + (y - 2)^2 + (z + 3)^2 = 25\\
# x + y + z = 0\\
# -2x + 3y - z = 7
# \end{matrix}\right.
# $$
# начальное приближение (0, 0, 0).
# Проверить подстановкой.

# %%
x, y, z = sympy.symbols('x y z')
System = [sympy.Eq((x-1)**2+(y-2)**2+(z+3)**2, 25), sympy.Eq(x+y+z, 0), sympy.Eq(-2*x+3*y-z, 7)]
root = sympy.nsolve(System, [x, y, z], [0, 0, 0], prec=20)
display(root)
display(*[j.subs([(x, root[0]), (y, root[1]), (z, root[2])]) for j in System])
# Out:
# Matrix([
# [-2.0860669992418382052],
# [ 1.2284832501895404487],
# [0.85758374905229775653]])
# True
# True
# True

# %% [markdown]
# ### Индивидуальное задание
# Построить графики функций $f(x)$ и $g(x)$, уточнить координаты точек пересечения, решая численно соответствующее уравнение. На  графике отметить и подписать буквами $А_1$, $A_2$, ... точки пересечения графиков.
#
# $f(x)=-\frac{x^2}{4}+x+10$
#
#
# $g(x) = 2x^2 + 10x + 10$

# %%
def f(x):
    return -x**2/4+x+10
def g(x):
    return 2*x**2+10*x+10
x = sympy.Symbol("x")
ax = plt.gca()  
X = np.linspace(-8,2, 100)
Y_f = f(X)
Y_g = g(X)
ax.plot(X, Y_f, color='green', label="$f(x) = -\\frac{x^2}{4}+x+10$")
ax.plot(X, Y_g, color='skyblue', label='$f(x) = 2x^2+10x+10$')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))
ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False)
ax.plot(0, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False)
roots = sympy.solve(sympy.Eq(f(x), g(x)), x)
y_coords = [f(x) for x in roots] 
ax.legend(loc='upper left')
for i in range(len(roots)): 
    ax.annotate('A' + str(i + 1),
            xy=(roots[i], y_coords[i]), xycoords='data',
            xytext=(roots[i]-0.2, y_coords[i]+3), textcoords='data')
ax.scatter(roots, y_coords)
