# %%
import sympy
from sympy import Matrix, S, Symbol, symbols, I, zeros, eye
from sympy import simplify, expand, expand_complex, latex
import numpy as np
from IPython.display import Latex

# %% [markdown]
# # Практическое занятие 17
# # Компьютерный практикум по алгебре на Python
# ## Матричные разложения: Холецкого, LDL, LU, QR. Жорданова форма.

# %% [markdown]
# ### Задание 1.
# Построить разложение Холецкого матриц
# $$
# M1=\left(
# \begin{matrix}
# 1&-3&0\\
# -3&-2&10\\
# 0&10&7
# \end{matrix}
# \right)
# \quad
# M2=\left(
# \begin{matrix}
# 18&1 - 2I& -2\\
# 1 + 2I&4&-3I\\
# -2&3I&5
# \end{matrix}
# \right)
# $$
# Проверить положительную определенность эрмитовой матрицы.

# %%
A = Matrix([[1, -3, 0], [-3, -2, 10], [0, 10, 7]])
B = Matrix([[18, 1 - 2*I, -2], [1 + 2*I, 4, -3*I], [-2, 3*I, 5]])
LA = A.cholesky(hermitian=False)
LB = B.cholesky()
display(Latex(f'L_A = {latex(LA)},\ L_AL_A^T - A= {latex(simplify(LA * LA.T - A))},\\\\\
        B.is\_positive\_definite\ {B.is_positive_definite},\\\\\
        L_B = {latex(LB)},\\\\\
        simplify(L_B) = {latex(simplify(LB))},\\\\\
        simplify(expand(L_B)) = {latex(simplify(expand(LB)))},\\\\\
        simplify(L_B*L_B^H - B) = {latex(simplify(LB * LB.H - B))}'))
# Out:
# L_A = \left[\begin{matrix}1 & 0 & 0\\-3 & \sqrt{11} i & 0\\0 & - \frac{10 \sqrt{11} i}{11} & \frac{\sqrt{1947}}{11}\end{matrix}\right],\ L_AL_A^T - A= \left[\begin{matrix}0 & 0 & 0\\0 & 0 & 0\\0 & 0 & 0\end{matrix}\right],\\        B.is\_positive\_definite\ True,\\        L_B = \left[\begin{matrix}3 \sqrt{2} & 0 & 0\\\frac{\sqrt{2} \left(1 + 2 i\right)}{6} & \sqrt{- \frac{\left(1 - 2 i\right) \left(1 + 2 i\right)}{18} + 4} & 0\\- \frac{\sqrt{2}}{3} & \frac{\frac{1}{9} + \frac{25 i}{9}}{\sqrt{- \frac{\left(1 - 2 i\right) \left(1 + 2 i\right)}{18} + 4}} & \sqrt{\frac{43}{9} - \frac{\left(\frac{1}{9} - \frac{25 i}{9}\right) \left(\frac{1}{9} + \frac{25 i}{9}\right)}{- \frac{\left(1 - 2 i\right) \left(1 + 2 i\right)}{18} + 4}}\end{matrix}\right],\\        simplify(L_B) = \left[\begin{matrix}3 \sqrt{2} & 0 & 0\\\frac{\sqrt{2} \left(1 + 2 i\right)}{6} & \frac{\sqrt{134}}{6} & 0\\- \frac{\sqrt{2}}{3} & \frac{\sqrt{134} \left(1 + 25 i\right)}{201} & \frac{\sqrt{12127}}{67}\end{matrix}\right],\\        simplify(expand(L_B)) = \left[\begin{matrix}3 \sqrt{2} & 0 & 0\\\frac{\sqrt{2} \left(1 + 2 i\right)}{6} & \frac{\sqrt{134}}{6} & 0\\- \frac{\sqrt{2}}{3} & \frac{\sqrt{134} \left(1 + 25 i\right)}{201} & \frac{\sqrt{12127}}{67}\end{matrix}\right],\\        simplify(L_B*L_B^H - B) = \left[\begin{matrix}0 & 0 & 0\\0 & 0 & 0\\0 & 0 & 0\end{matrix}\right]

# %% [markdown]
# ### Задание 2.
# Построить  LDL разложение для матриц Задания 1.

# %%
A = Matrix([[1, -3, 0], [-3, -2, 10], [0, 10, 7]])
B = Matrix([[18, 1 - 2*I, -2], [1 + 2*I, 4, -3*I], [-2, 3*I, 5]])
LA, DA = A.LDLdecomposition(hermitian=False)
LB, DB = B.LDLdecomposition()
LA, DA, LB, DB = [simplify(item) for item in (LA, DA, LB, DB)]
display(Latex("""A = {}\\\\A.is\_positive\_definite\ {}\\\\\
L_A = {}, D_A = {},\\\\L_AD_AL_A^T = {},\\\\\
B = {}\\\\\
B.is\_positive\_definite\ {}\\\\L_B = {}, D_B = {},\\\\\
L_BD_BL_B^H = {}\
""".format(*[latex(item) for item in (A, A.is_positive_definite,
                                      LA, DA, LA * DA * LA.T,
                                      B, B.is_positive_definite,
                                      LB, simplify(DB),
                                      simplify(LB * DB * LB.H))])))
# Out:
# A = \left[\begin{matrix}1 & -3 & 0\\-3 & -2 & 10\\0 & 10 & 7\end{matrix}\right]\\A.is\_positive\_definite\ \text{False}\\L_A = \left[\begin{matrix}1 & 0 & 0\\-3 & 1 & 0\\0 & - \frac{10}{11} & 1\end{matrix}\right], D_A = \left[\begin{matrix}1 & 0 & 0\\0 & -11 & 0\\0 & 0 & \frac{177}{11}\end{matrix}\right],\\L_AD_AL_A^T = \left[\begin{matrix}1 & -3 & 0\\-3 & -2 & 10\\0 & 10 & 7\end{matrix}\right],\\B = \left[\begin{matrix}18 & 1 - 2 i & -2\\1 + 2 i & 4 & - 3 i\\-2 & 3 i & 5\end{matrix}\right]\\B.is\_positive\_definite\ \text{True}\\L_B = \left[\begin{matrix}1 & 0 & 0\\\frac{1}{18} + \frac{i}{9} & 1 & 0\\- \frac{1}{9} & \frac{2}{67} + \frac{50 i}{67} & 1\end{matrix}\right], D_B = \left[\begin{matrix}18 & 0 & 0\\0 & \frac{67}{18} & 0\\0 & 0 & \frac{181}{67}\end{matrix}\right],\\L_BD_BL_B^H = \left[\begin{matrix}18 & 1 - 2 i & -2\\1 + 2 i & 4 & - 3 i\\-2 & 3 i & 5\end{matrix}\right]

# %% [markdown]
# ### Задание  3.
# Построить  LU разложение для матрицы
# $$
# V=\left(
# \begin{matrix}
# 5&-2 - I&3 - 4I&1 + 4I\\
# 1 - I&-2&5 - I&2 - I\\
# 5&6 + I&0&5
# \end{matrix}
# \right)
# $$

# %%
V = Matrix([[5, -2 - I, 3 - 4*I, 1 + 4*I], [1 - I, -2, 5 - I, 2 - I], [5, 6 + I, 0, 5]])
number_of_rows = V.shape[0]
V = V.row_join(Matrix([k + 1 for k in range(number_of_rows)]))
L, U, perm = V.LUdecomposition()
MLU = simplify(expand((L * U).permuteBkwd(perm)))
L, U, LU, MLU = [simplify(expand(item)) for item in (L, U, L * U, MLU)]
P = eye(number_of_rows).permuteFwd(perm)
display(Latex("""V = {}\\\\perm = {}, L = {}, U = {}\\\\
LU = {}\\\\LU.permuteBkwd(perm) = {}\\\\PV = LU\ {}""".format(*map(latex, (V, perm, L, U, LU, MLU, P * V == LU)))))
# Out:
# V = \left[\begin{matrix}5 & -2 - i & 3 - 4 i & 1 + 4 i & 1\\1 - i & -2 & 5 - i & 2 - i & 2\\5 & 6 + i & 0 & 5 & 3\end{matrix}\right]\\perm = \left[ \left[ 1, \  2\right]\right], L = \left[\begin{matrix}1 & 0 & 0\\1 & 1 & 0\\\frac{1}{5} - \frac{i}{5} & - \frac{29}{170} + \frac{3 i}{170} & 1\end{matrix}\right], U = \left[\begin{matrix}5 & -2 - i & 3 - 4 i & 1 + 4 i & 1\\0 & 8 + 2 i & -3 + 4 i & 4 - 4 i & 2\\0 & 0 & \frac{809}{170} + \frac{193 i}{170} & \frac{137}{85} - \frac{40 i}{17} & \frac{182}{85} + \frac{14 i}{85}\end{matrix}\right]\\
# LU = \left[\begin{matrix}5 & -2 - i & 3 - 4 i & 1 + 4 i & 1\\5 & 6 + i & 0 & 5 & 3\\1 - i & -2 & 5 - i & 2 - i & 2\end{matrix}\right]\\LU.permuteBkwd(perm) = \left[\begin{matrix}5 & -2 - i & 3 - 4 i & 1 + 4 i & 1\\1 - i & -2 & 5 - i & 2 - i & 2\\5 & 6 + i & 0 & 5 & 3\end{matrix}\right]\\PV = LU\ \text{True}

# %% [markdown]
# ### Задание  4.
# Построить  QR разложение для матрицы
# $$
# A=\left(
# \begin{matrix}
# 3 + i&  2 & -i & 4 - 2i\\
# -2 & -3 &  i & -3 + i\\
# 1 + i & -1 &  0 & 1 - i\\
# -1 + i &  -4 & i & -2
# \end{matrix}
# \right)
# $$
# показать, что $A = QR$.

# %%
A = Matrix([[3 + I, 2, -I, 4 - 2*I], [-2, -3, I, -3 + I], [1 + I, -1, 0, 1 - I], [-1 + I, -4, I, -2]])
Q, R = A.QRdecomposition()
AQR = Q * R
Q, R, AQR = [simplify(expand(item)) for item in (Q, R, AQR)]
display(Latex("""A = {}\\\\Q = {}, R = {}\\\\
QR = {}\\\\A = QR\ {}""".format(*map(latex, (A, Q, R, AQR, A == AQR)))))
# Out:
# A = \left[\begin{matrix}3 + i & 2 & - i & 4 - 2 i\\-2 & -3 & i & -3 + i\\1 + i & -1 & 0 & 1 - i\\-1 + i & -4 & i & -2\end{matrix}\right]\\Q = \left[\begin{matrix}\frac{\sqrt{2} \left(3 + i\right)}{6} & - \frac{\sqrt{17} \left(1 + 4 i\right)}{51}\\- \frac{\sqrt{2}}{3} & \frac{\sqrt{17} \left(-4 + i\right)}{51}\\\frac{\sqrt{2} \left(1 + i\right)}{6} & - \frac{\sqrt{17} \left(5 + 3 i\right)}{51}\\\frac{\sqrt{2} \left(-1 + i\right)}{6} & - \frac{\sqrt{17} \left(9 + 2 i\right)}{51}\end{matrix}\right], R = \left[\begin{matrix}3 \sqrt{2} & \frac{\sqrt{2} \left(5 + i\right)}{2} & - \sqrt{2} i & \sqrt{2} \left(3 - 2 i\right)\\0 & \sqrt{17} & \frac{\sqrt{17} \left(1 - 4 i\right)}{17} & \frac{\sqrt{17} \left(11 + 7 i\right)}{17}\end{matrix}\right]\\
# QR = \left[\begin{matrix}3 + i & 2 & - i & 4 - 2 i\\-2 & -3 & i & -3 + i\\1 + i & -1 & 0 & 1 - i\\-1 + i & -4 & i & -2\end{matrix}\right]\\A = QR\ \text{True}

# %% [markdown]
# ### Задание  5.
# Построить  жорданову форму для матрицы
# $$
# K=\left(
# \begin{matrix}
# 6 &  5 & -2 & -3\\
# -3 & -1 &  3 &  3\\
# 2 &  1 & -2 &  -3\\
# -1 & 1 & 5 & 5
# \end{matrix}
# \right)
# $$

# %%
K = Matrix([[6,  5, -2, -3], [-3, -1,  3,  3], [2,  1, -2, -3], [-1,  1,  5,  5]])
P, J = K.jordan_form()
P, J = [simplify(expand(item)) for item in (P, J)]
display(Latex('P = {}, J = {}\\\\PJP^{{-1}} = {}, K  = {}'.format(*map(latex, (P, J, P * J * P ** (-1), K)))))
# Out:
# P = \left[\begin{matrix}4 & 1 & 5 & 0\\-3 & 0 & -3 & 1\\2 & 0 & 1 & 0\\-1 & 0 & 1 & 0\end{matrix}\right], J = \left[\begin{matrix}2 & 1 & 0 & 0\\0 & 2 & 0 & 0\\0 & 0 & 2 & 1\\0 & 0 & 0 & 2\end{matrix}\right]\\PJP^{-1} = \left[\begin{matrix}6 & 5 & -2 & -3\\-3 & -1 & 3 & 3\\2 & 1 & -2 & -3\\-1 & 1 & 5 & 5\end{matrix}\right], K  = \left[\begin{matrix}6 & 5 & -2 & -3\\-3 & -1 & 3 & 3\\2 & 1 & -2 & -3\\-1 & 1 & 5 & 5\end{matrix}\right]

# %% [markdown]
# ### Индивидуальное задание #33.
# Решить с помощью  QR разложения матрицы
# $A$
# систему линейных уравнений
# $AX = b$.
#
# $$A = \begin{pmatrix}
# 8 & -4 & -9 & 5 \\
# 3 & 5 & 5 & -8 \\
# 20 & 3 & 1 & -9 \\
# 17 & -2 & -4 & -1
# \end{pmatrix}$$
#
# $$b = \begin{pmatrix}
#  8 \\
# -7 \\
# 2 \\
# 12
# \end{pmatrix}$$

# %%
B = Matrix([[8, -4, -9, 5], [3, 5, 5, -8], [20, 3, 1, -9], [17, -2, -4, -1]])
b = Matrix([8, -7, 2, 12])
Bb = B.row_join(b)
print(f"""B.rank = {B.rank()}, Bb.rank = {Bb.rank()},
B.rank == Bb.rank(): {B.rank() == Bb.rank()}""")
# Out:
# B.rank = 3, Bb.rank = 4,
# B.rank == Bb.rank(): False

# %%
X = B.QRsolve(b)
display(X)
# Out:
# Matrix([
# [ 179/351],
# [-929/351],
# [   20/27]])

# %%
X = X.col_join(Matrix([0]))
delta = B * X - b
display(Latex('X = {}, delta = {}, delta.norm(2) = {}'.format(*map(latex, (X, delta, delta.norm(2))))))
# Out:
# X = \left[\begin{matrix}\frac{179}{351}\\- \frac{929}{351}\\\frac{20}{27}\\0\end{matrix}\right], delta = \left[\begin{matrix}0\\-1\\1\\-1\end{matrix}\right], delta.norm(2) = \sqrt{3}
