# %%
import numpy as np
import sympy
from sympy import Expr, Eq, latex, plot_implicit, tan, cot
from sympy.core import S, pi, sympify
from sympy.core.logic import fuzzy_bool
from sympy.core.numbers import Rational, oo
from sympy.core.compatibility import ordered
from sympy.core.symbol import Dummy, _uniquely_named_symbol, _symbol
from sympy.simplify import simplify, trigsimp
from sympy.functions.elementary.miscellaneous import sqrt, Max
from sympy.functions.elementary.trigonometric import cos, sin
from sympy.functions.special.elliptic_integrals import elliptic_e
from sympy.geometry.exceptions import GeometryError
from sympy.geometry.line import Ray2D, Segment2D, Line2D, LinearEntity3D
from sympy.polys import DomainError, Poly, PolynomialError
from sympy.polys.polyutils import _not_a_coeff, _nsort
from sympy.solvers import solve
from sympy.solvers.solveset import linear_coeffs
from sympy.utilities.misc import filldedent, func_name
from sympy.geometry.entity import GeometryEntity, GeometrySet
from sympy.geometry.point import Point, Point2D, Point3D
from sympy.geometry.line import Line, Segment
from sympy.geometry.util import idiff
import matplotlib.pyplot as plt
from IPython.display import Math, Latex

# %% [markdown]
# # Практическое занятие 14
# # Компьютерный практикум по алгебре на Python
# ## Кривые второго порядка на плоскости: гипербола

# %%
class Hyperbola(GeometrySet):
    """
     Attributes
    ==========
    center
    hradius
    vradius
    eccentricity
    periapsis
    focus_distance
    foci
    ==========
    конструктор __new__
    скопирован из Эллипса,
    изменена формула для  hradius и vradius через эсцентриситет
    """
    def __new__(
        cls, center=None, hradius=None, vradius=None, eccentricity=None, **kwargs):
        hradius = sympify(hradius)
        vradius = sympify(vradius)

        eccentricity = sympify(eccentricity)

        if center is None:
            center = Point(0, 0)
        else:
            center = Point(center, dim=2)

        if len(center) != 2:
            raise ValueError('The center of "{0}" must be a two dimensional point'.format(cls))

        if len(list(filter(lambda x: x is not None, (hradius, vradius, eccentricity)))) != 2:
            raise ValueError(filldedent('''
                Exactly two arguments of "hradius", "vradius", and
                "eccentricity" must not be None.'''))

        if eccentricity is not None:
            if hradius is None:
                hradius = vradius/sqrt( eccentricity**2 - 1)
            elif vradius is None:
                vradius = hradius*sqrt( eccentricity**2 - 1)

        if hradius == 0:
            return "Line"
        if vradius == 0:
            return "Rays"
        return GeometryEntity.__new__(cls, center, hradius, vradius, **kwargs)
    
    @property
    def ambient_dimension(self):
        return 2
    
    @property
    def center(self):
        return self.args[0]

    @property
    def hradius(self):
        return self.args[1]
    
    @property
    def vradius(self):
        return self.args[2]
    @property
    def focus_distance(self):
        return sqrt(self.hradius**2 + self.vradius**2)
    
    @property
    def eccentricity(self):
        """The eccentricity of the ellipse."""
        return self.focus_distance/self.hradius
    
    @property
    def periapsis(self):
        """The apoapsis of the hyperbola.
        The smallest distance between the focus and the contour."""
        return self.focus_distance-self.hradius
    @property
    def foci(self):
        return (self.center + Point(-self.focus_distance, 0), self.center + Point(self.focus_distance, 0))
    
    @property
    def major(self):
        return self.hradius
    
    @property
    def minor(self):
        return self.vradius
    
    def equation(self, x='x', y='y', _slope=None, equation=False):
        """
        Returns the equation of a hyperbola aligned with the x and y axes;
        when slope is given, the equation returned corresponds to a hyperbola 
        with a major axis having that slope.
        Parameters
        ==========
        x : str, optional
            Label for the x-axis. Default value is 'x'.
        y : str, optional
            Label for the y-axis. Default value is 'y'.
        _slope : Expr, optional
                The slope of the major axis. Ignored when 'None'.
        Returns
        =======
        equation : sympy expression   """

        x = _symbol(x, real=True)
        y = _symbol(y, real=True)

        dx = x - self.center.x
        dy = y - self.center.y

        if _slope is not None:
            L = (dy - _slope*dx)**2
            l = (_slope*dy + dx)**2
            h = 1 + _slope**2
            a = h*self.major**2
            b = h*self.minor**2
            res= l/a - L/b 

        else:
            t1 = (dx/self.hradius)**2
            t2 = (dy/self.vradius)**2
            res = t1 - t2 
        if not equation:
            return res - 1
        else:
            return Eq(res, 1)

    def directrix(self, x='x', y='y', _slope=None, equation=False):
        x = _symbol(x, real=True)
        a = self.hradius
        b = self.vradius
        c = self.focus_distance
        x0 = self.center[0]
        y0 = self.center[1]
        if _slope is None:
            if not equation:
                return x - x0 + a**2/c, x - x0 - a**2/c
            return Eq(x, x0 + a**2/c), Eq(x, x0 - a**2/c)
        else:
            if not equation:
                return y - y0 + (x - x0)/_slope - a**2/c*(1 + 1/_slope)**S.Half, y - y0 + (x - x0)/_slope + a**2/c*(1 + 1/_slope)**S.Half
            return Eq(y, y0 - (x - x0)/_slope - a**2/c*(1 + 1/_slope)**S.Half), Eq(y, y0 - (x - x0)/_slope + a**2/c*(1 + 1/_slope)**S.Half)

    def asymptote(self, x='x', y='y', _slope=None, equation=False):
        x = _symbol(x, real=True)
        y = _symbol(y, real=True)
        a = self.hradius
        b = self.vradius
        c = self.focus_distance
        x0 = self.center[0]
        y0 = self.center[1]
        if _slope is None:
            if not equation:
                return y - y0 + b/a*(x - x0), y - y0 + b/a*(x - x0)
            return Eq(y, y0 + b/a*(x - x0)), Eq(y, y0 - b/a*(x - x0))
        else:
            if not equation:
                return y - y0 - (b + a*_slope)/(a - b*_slope)*(x - x0), y - y0 - (-b + a*_slope)/(a + b*_slope)*(x - x0)
            return Eq(y, y0 + (b + a*_slope)/(a - b*_slope)*(x - x0)), Eq(y, y0 + (-b + a*_slope)/(a + b*_slope)*(x - x0))

# %% [markdown]
# # Занятие 15
# # Алгебра
# ### Задание 1.
# Построить гиперболу с центром в точке А(1, 2), полуосями 12 и 5. Вывести на экран эксцентриситет, фокусное расстояние, фокусы (с координатами), periapsis и уравнение гиперболы.

# %%
Hyp1 = Hyperbola(Point(1,2), hradius = 12, vradius = 5)
print(f'эксцентриситет: {Hyp1.eccentricity}')
print(f'фокусное расстояние: {Hyp1.focus_distance}')
print(f'фокусы: {Hyp1.foci}')
print(f'periapsis: {Hyp1.periapsis}')
display(Hyp1.equation(equation=True))
# Out:
# эксцентриситет: 13/12
# фокусное расстояние: 13
# фокусы: (Point2D(-12, 2), Point2D(14, 2))
# periapsis: 1
# Eq((x/12 - 1/12)**2 - (y/5 - 2/5)**2, 1)

# %% [markdown]
# ### Задание 2.
# Добавить в описание класса гипербол методы
#
# asymptote(self, x='x', y='y', equation=False)
#
# directrix(self, x='x', equation=False)
#
# Для гиперболы Задания 1 вывести на экран уравнения асимптот и директрис.

# %%
display(*Hyp1.asymptote(equation=True))
display(*Hyp1.directrix(equation=True))
# Out:
# Eq(y, 5*x/12 + 19/12)
# Eq(y, 29/12 - 5*x/12)
# Eq(x, 157/13)
# Eq(x, -131/13)

# %% [markdown]
# ### Задание 3.
# Вывести на экран уравнение гиперболы из задания 1 с поворотом на 30 градусов против часовой стрелки относительно ее центра.
# Изобразить повернутую гиперболу с помощью plot_implicit.

# %%
display(Hyp1.equation(_slope=1/(3**(S(1)/2)), equation=True))
eq1 = Hyp1.equation(x='x', y='y', _slope=1/(3**(S(1)/2)))
dict_free = {str(a): a for a in eq1.free_symbols}
plot_implicit(eq1, (dict_free['x'], -30, 30), (dict_free['y'], -20, 20),
                  line_color='r', aspect_ratio=(1, 1),
                  adaptive=False)
# Out:
# Eq((x + sqrt(3)*(y - 2)/3 - 1)**2/192 - 3*(y - sqrt(3)*(x - 1)/3 - 2)**2/100, 1)

# %% [markdown]
# ## Уравнения директрис и асимптот при повороте на угол $\alpha$
# Пусть  $a$ - горизонтальная полуось, $c$ - фокусное расстояние, $x_0$ - горизонтальная координата центра гиперболы, тогда уравнение директрис
# $$
# x = x_0 \pm \frac{a^2}{c}
# $$
# При повороте на угол $\alpha$ получается уравнение
# $$
# y = y_0 -{\rm ctg} \alpha(x - x_0) \pm \frac{a^2}{c}\sqrt{1 + {\rm ctg} \alpha}
# $$
# Уравнение асимптоты
# $$
# y = y_0 \pm \frac{b}{a}(x - x_0)
# $$
# При повороте на угол $\alpha$ получаются уравнения
# \begin{align*}
# y_1 = y_0 + k_1(x - x_0), \quad
# y_2 = y_0 + k_2(x - x_0), \\
# k_1 = \frac{b + a{\rm tg} \alpha}{a - b{\rm tg} \alpha},\quad
# k_2 = \frac{-b + a{\rm tg} \alpha}{a + b{\rm tg} \alpha}
# \end{align*}
# ### Задание 4.
# Изобразить гиперболу Задания 3 (т.е. повернутую на угол) и ее асимптоты и директрисы на одном графике plot_implicit.

# %%
x, y = sympy.symbols("x y")
eq1 = Hyp1.equation(x=x, y=y, _slope=1/(3**(S(1)/2)))
p = plot_implicit(eq1,
                  (x, -40, 40),
                  (y, -40, 40),
                  aspect_ratio=(1, 1),
                  line_color = 'r',
                  show=False,
                  adaptive=False)
for line in (Hyp1.asymptote(x=x, y=y, equation=False, _slope=1/(3**(S(1)/2)))+Hyp1.directrix(x=x, y=y, equation=False, _slope=1/(3**(S(1)/2)))):
    display(Eq(line, 0))
    p.extend(plot_implicit(line,
                (x, -40, 40),
                (y, -40, 40),
                aspect_ratio=(1, 1),
                line_color = 'g',
                show=False,
                adaptive=False))
p.show()
# Out:
# Eq(y - (5 + 4*sqrt(3))*(x - 1)/(12 - 5*sqrt(3)/3) - 2, 0)
# Eq(y - (-5 + 4*sqrt(3))*(x - 1)/(5*sqrt(3)/3 + 12) - 2, 0)
# Eq(y + sqrt(3)*(x - 1) - 144*sqrt(1 + sqrt(3))/13 - 2, 0)
# Eq(y + sqrt(3)*(x - 1) - 2 + 144*sqrt(1 + sqrt(3))/13, 0)

# %% [markdown]
# ###  Индивидуальное задание
# Определить гиперболу с центром в $Point2D\left(-1, 5\right)$, вертикальной полуосью  $3 \sqrt{2} / 4$, эксцентриситетом $3$.  Вывести на экран эксцентриситет, фокусное расстояние, фокусы (с координатами), periapsis, уравнение гиперболы, уравнения асимптот и директрис.
#
# Изобразить гиперболу, повернутую на $\pi / 3$, по часовой стрелке относительно ее центра, соответствующие асимптоты и директрисы. Вывести на экран уравнение повернутой гиперболы.

# %%
Hyp3 = Hyperbola(Point(-1, 5), vradius = 3*2**S.Half/4, eccentricity = 3)
props = {'center': Hyp3.center, 'hradius': Hyp3.hradius,
         'vradius': Hyp3.vradius, 
         'eccentricity': Hyp3.eccentricity, 'focus\_distance': Hyp3.focus_distance, 
         'foci': Hyp3.foci, 'periapsis': Hyp3.periapsis, 'equation': Hyp3.equation(equation=True),
         'asymptote': Hyp3.asymptote(equation=True), 'directrix':Hyp3.directrix(equation=True)}
display(*[Latex(f'{key} = {latex(props[key])}') for key in props.keys()])
x, y = sympy.symbols("x y")
eq3 = Hyp3.equation(x=x, y=y, _slope=-3**(S(1)/2))
display(Hyp3.equation(_slope=-3**(S(1)/2), equation=True))
p = plot_implicit(eq3,
                  (x, -4, 2),
                  (y, 2, 8),
                  aspect_ratio=(1, 1),
                  line_color = 'r',
                  show=False,
                  adaptive=False,
                  points=400)
for line in (Hyp3.asymptote(x=x, y=y, equation=False, _slope=-3**(S(1)/2))+Hyp3.directrix(x=x, y=y, equation=False, _slope=-3**(S(1)/2))):
    p.extend(plot_implicit(line,
                (x, -4, 2),
                (y, 2, 8),
                aspect_ratio=(1, 1),
                line_color = 'g',
                show=False,
                adaptive=False))
p.show()
# Out:
# center = Point2D\left(-1, 5\right)
# hradius = \frac{3}{8}
# vradius = \frac{3 \sqrt{2}}{4}
# eccentricity = 3
# focus\_distance = \frac{9}{8}
# foci = \left( Point2D\left(- \frac{17}{8}, 5\right), \  Point2D\left(\frac{1}{8}, 5\right)\right)
# periapsis = \frac{3}{4}
# equation = \left(\frac{8 x}{3} + \frac{8}{3}\right)^{2} - \frac{8 \left(y - 5\right)^{2}}{9} = 1
# asymptote = \left( y = 2 \sqrt{2} \left(x + 1\right) + 5, \  y = - 2 \sqrt{2} \left(x + 1\right) + 5\right)
# directrix = \left( x = - \frac{7}{8}, \  x = - \frac{9}{8}\right)
# Eq(16*(x - sqrt(3)*(y - 5) + 1)**2/9 - 2*(y + sqrt(3)*(x + 1) - 5)**2/9, 1)
